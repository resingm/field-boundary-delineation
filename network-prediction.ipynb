# %% [markdown]
# # Automatic delineation of field boundaries on satellite images
#
# ```
# TODO: Add intro
# ```

# %%
# Mount google drive folder
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import os
import numpy as np
import typing
import gdal
import keras
import tensorflow as tf

from skimage import exposure

# Install keras-unet library for python
#%pip uninstall keras-unet
# %pip install git+https://github.com/karolzak/keras-unet

# define dataset directory
from google.colab import drive

BASE_PATH = "/content/drive/My Drive/Minor: EO Project Group 3"
DATA_PATH = BASE_PATH + "/Classified Data/"
NETWORK_PATH = BASE_PATH + "/Networks"
IMAGE_PATH = "/Original"
LABEL_PATH = "/Classified"
PREDICTION_PATH = "/Prediction"

INCLUDE_FOLDERS = ["Flevoland", "Friesland", "Gelderland", "Limburg", "Overijssel", "Zeeland", "Zuid-Holland"]

LEGEND = {
    1: 'Other',
    2: 'Field Boundary'
}


# To assess the accuracy you have to define the networks UUID and name here
NETWORK_UUID = "371dd574-5b78-11eb-8f58-0242ac1c0002"

# Allowed Values:
#   * FCNDK3
#   * FCNDK4
#   * FCNDK5
#   * FCNDK6
#   * UNet2
#   * UNet3
NETWORK_NAME = "UNet3"


# To compile the model, also the optimizer has to be defined
NETWORK_OPTIMIZER = "Adam"

# Ensure you use the same optimizer parameters as in the training run
SGD_LEARNING_RATE = 0.01
SGD_MOMENTUM = 0.9
ADAM_LEARNING_RATE = 0.01
ADAM_BETA_1 = 0.9
ADAM_BETA_2 = 0.999
ADAM_EPSILON= 1e-07


# Remark: All information in here could have been loaded from the training
#         configuration file as well. However, we missed the chance to export
#         the configuration as a machine readable type, e.g. JSON.
#         Thus, we did not parse the config from the readme manually but set the
#         parameters manually in here.
# Out:
# Collecting git+https://github.com/karolzak/keras-unet
#   Cloning https://github.com/karolzak/keras-unet to /tmp/pip-req-build-53le5jy1
#   Running command git clone -q https://github.com/karolzak/keras-unet /tmp/pip-req-build-53le5jy1
# Requirement already satisfied (use --upgrade to upgrade): keras-unet==0.1.2 from git+https://github.com/karolzak/keras-unet in /usr/local/lib/python3.6/dist-packages
# Building wheels for collected packages: keras-unet
#   Building wheel for keras-unet (setup.py) ... done
#   Created wheel for keras-unet: filename=keras_unet-0.1.2-cp36-none-any.whl size=16994 sha256=c885a61adcae435b2c2c3980f5e097dae131797ae966ec7ed925d9775c6fa9e6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jy0navtv/wheels/b3/3a/85/c3df1c96b5d83dcd2c09b634e72a98cafcf12a52501ac5cd77
# Successfully built keras-unet

# %%
# ################################################################
# Prerequisites for the network
#
# Includes a few helper functions which will be used to create and
# evaluate the network, the training and the accuracy.
# ################################################################

import imp, h5py
import dill, pickle
import uuid
imp.reload(h5py)

from tensorflow.python.keras import backend as K
sess = K.get_session()

from tensorflow.compat.v1.keras.backend import set_session


# Tensorflow configuration
config = tf.compat.v1.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.2
set_session(tf.compat.v1.Session(config=config))



# Helper functions for the networks

# ################################################################
# Helper functions - import/export of network
#
# These two functions help to export the network and import it.
# That allows to skip the training at a later stage.
# ################################################################

class ModelHistory:
    """Just a small container class to hold relevant information of a trained
    model.
    """

    def __init__(self, uuid, name, model, history, readme):
        """Create a new instance of this class
        :param uuid: A unique identifier of the network
        :param name: The networks name
        :param model: The pretrained model
        :param history: The training history of the model
        :param readme: A small readme with a summary of training parameters
        """
        self.uuid = uuid
        self.name = name
        self.model = model
        self.history = history
        self.readme = readme


def get_file_names(uuid, name):
    """Generates three file names for the model, weights and history file and
    the networks readme.

    File name order of returned tuple:
        * readme
        * model
        * weights
        * history

    :param uuid: Universal unique identifier of a trained network
    :param name: The networks name
    :return: Tuple with files in the order mentioned above
    """
    base = f"{NETWORK_PATH}/{str(uuid)}-{name}"

    f_readme = f"{base}-readme.txt"
    f_model = f"{base}-model.h5"
    f_weights = f"{base}-weights.h5"
    f_history = f"{base}-history"

    return (f_readme, f_model, f_weights, f_history)


def export_model(m: ModelHistory):
    """If a model is sufficiently trained, it can be exported. This allows to
    simply save the models state and the training history. Whenever one want to
    use the model the next time, the training can be skipped, since the trained
    model can just be imported from files.

    :param model_history: The trained model and history to be stored
    """
    f_readme, f_model, f_weights, f_history = get_file_names(m.uuid,m.name)

    # save readme
    with open(f_readme, 'w') as f:
        f.write(m.readme)
    print(f"Exported README: {f_readme}")

    # save models & weights
    m.model.save(f_model)
    print(f"Exported model: {f_model}")
    m.model.save_weights(f_weights)
    print(f"Exported weights: {f_weights}")

    # save history
    with open(f_history, "wb") as f:
        pickle.dump(m.history, f)
    print(f"Exported history: {f_history}")

def import_model(uuid, name):
    """Previously exported models can be imported with this funciton.
    :param uuid: The networks uuid
    :param name: The networks name
    :return: Instance of ModelHistory
    """
    f_readme, f_model, f_weights, f_history = get_file_names(uuid, name)

    # Load readme
    with open(f_readme, 'r') as f:
        readme = "".join(f.readlines())
    print(f"Imported README: {f_readme}")

    # Load model & weights
    model = tf.keras.models.load_model(f_model)
    print(f"Imported model: {f_model}")
    model.load_weights(f_weights)
    print(f"Imported weights: {f_weights}")

    # Load history
    with open(f_history, 'rb') as f:
        history = pickle.load(f)
    print(f"Imported history: {f_history}")

    return ModelHistory(uuid, name, model, history, readme)

# %%
# ################################################################
# Loading input data
#
# Input data is loaded into two dictionaries: 
#
# images: contains the 4-band images. The values are loaded as ints.
# labels: contains 3D arrays in which each pixel is assigned with 
#         a label "1" = other and "2" = field boundary
#
# ################################################################


def key_generator(file_name):
    """Generates the key of a file based on the file name. The resulting key is
    a tuple of the province as string & the file number index as int,
    e.g. ("gelderland", 29)
    """
    file_name = file_name.lower()
    file_name = file_name.replace("classified_", "")
    file_name = file_name.replace("original_", "")
    file_name = file_name.replace(".tif", "")
    # TODO: Some images are named incorrectly
    #       (e.g. no '_' between the province name and the image index)
    (province, index) = tuple(file_name.split("_"))
    index = int(index)
    return (province, index)

def gtiff_to_array(file_path):
    """Takes a file path and returns a tif file as a 3-dimensional numpy array, width x height x bands."""
    data = gdal.Open(file_path)
    bands = [data.GetRasterBand(i+1).ReadAsArray() for i in range(data.RasterCount)]
    return np.stack(bands, axis=2)

def transform_classification_image(input):
    """Takes the classification image input (in RGB format as 3D array) and 
    creates a 2D array out of this. The innermost array expects either values of
    [0, 0, 0] of [255, 255, 255] since this is the colouring we assigned to the
    classified images.

    :param input: 3D input image (classification)
    :return: 2D array image with labels 1 for 'other' and 2 for 'field_boundaries'
    """

    # Out of the 3D input array it takes the "max" element out of the array
    # This will either be 0 or 255. This function is just called to transform 
    # the 3D array to a 2D array.
    result = np.reshape(np.max(input, axis=2), (input.shape[0], input.shape[1], 1))

    # Now the array consists of pixels with values "0" or "255". We transform
    # each value, that is larger than 0 (i.e. 255) and assign the label "2" to
    # it. Each other element (i.e. 0) will get assigned the label "1".
    result = np.where(result > 0, 2, 1)
    return result

# Dictionaries which contain the input data
x_dict = {}
y_dict = {}

# Iterate through defined folders and load all image data into the dictionaries
# image_data and label_data. Images can be accessed with (<province>, <index>)
for folder in INCLUDE_FOLDERS:
    original = DATA_PATH + folder + IMAGE_PATH
    classified = DATA_PATH + folder + LABEL_PATH
    for f in os.listdir(original): 
        key = key_generator(f)
        x_dict[key] = gtiff_to_array(original + "/" + f)

    for f in os.listdir(classified): 
        key = key_generator(f)
        value = gtiff_to_array(classified + "/" + f) 
        # Transform the classification image from RGB to labels "1" and "2"
        value = transform_classification_image(value)
        y_dict[key] = value


print(f"Total number of image & label tiles: {len(x_dict)}")
# Out:
# Total number of image & label tiles: 122

# %%
# ################################################################
# Normalizing images
# 
# Normalizing all input images into values in the interval [0, 1].
# All bands are normalized seperately, which means, the min & max
# of each band is calculated based on each band of the image data.
# ################################################################

def normalize(val, min, max):
    """Normalizes the value of a single pixel. Takes into account the minimum,
    and maximum value.

    v_normalized = (v - min) / (max - min)

    :param val: integer value
    :param min: integer minimum
    :param max: integer maximum
    :return: single floating point number in [0, 1]
    """
    # TODO: check if necessary, otherwise delete
    return (val - min) / (max - min)


def normalize_array(arr):
    """Takes a 3D array as input, iterates over the bands and normalizes those.

    :param arr: input array (original image data) 
    :return: normalized data with values between 0 and 1
    """
    arr_norm = np.zeros(arr.shape, dtype=np.float32)

    for i in range(arr.shape[2]):
        min = arr[:, :, i].min()
        max = arr[:, :, i].max()

        arr_norm = (arr - min) / (max - min)
    
    return arr_norm


for k, v in x_dict.items():
    x_dict[k] = normalize_array(v)
    print(f"Performed normalization of {k[0]}_{k[1]}")
# Out:
# Performed normalization of flevoland_21
# Performed normalization of flevoland_22
# Performed normalization of flevoland_20
# Performed normalization of flevoland_34
# Performed normalization of flevoland_36
# Performed normalization of flevoland_37
# Performed normalization of flevoland_50
# Performed normalization of flevoland_52
# Performed normalization of flevoland_51
# Performed normalization of flevoland_66
# Performed normalization of flevoland_64
# Performed normalization of flevoland_65
# Performed normalization of flevoland_79
# Performed normalization of flevoland_80
# Performed normalization of flevoland_95
# Performed normalization of flevoland_93
# Performed normalization of flevoland_94
# Performed normalization of flevoland_107
# Performed normalization of flevoland_108
# Performed normalization of friesland_123
# Performed normalization of friesland_134
# Performed normalization of friesland_135
# Performed normalization of friesland_137
# Performed normalization of friesland_136
# Performed normalization of friesland_138
# Performed normalization of friesland_149
# Performed normalization of friesland_148
# Performed normalization of friesland_150
# Performed normalization of friesland_151
# Performed normalization of friesland_152
# Performed normalization of friesland_161
# Performed normalization of friesland_163
# Performed normalization of friesland_162
# Performed normalization of friesland_165
# Performed normalization of friesland_164
# Performed normalization of friesland_166
# Performed normalization of friesland_175
# Performed normalization of friesland_177
# Performed normalization of friesland_176
# Performed normalization of friesland_178
# Performed normalization of friesland_179
# Performed normalization of friesland_180
# Performed normalization of friesland_195
# Performed normalization of gelderland_29
# Performed normalization of gelderland_30
# Performed normalization of gelderland_37
# Performed normalization of limburg_82
# Performed normalization of limburg_96
# Performed normalization of limburg_110
# Performed normalization of limburg_165
# Performed normalization of limburg_166
# Performed normalization of overijssel_1
# Performed normalization of overijssel_2
# Performed normalization of overijssel_5
# Performed normalization of overijssel_3
# Performed normalization of overijssel_4
# Performed normalization of overijssel_6
# Performed normalization of overijssel_7
# Performed normalization of overijssel_14
# Performed normalization of overijssel_15
# Performed normalization of overijssel_17
# Performed normalization of overijssel_16
# Performed normalization of overijssel_18
# Performed normalization of overijssel_19
# Performed normalization of overijssel_20
# Performed normalization of overijssel_21
# Performed normalization of overijssel_29
# Performed normalization of overijssel_31
# Performed normalization of overijssel_30
# Performed normalization of overijssel_32
# Performed normalization of overijssel_33
# Performed normalization of overijssel_35
# Performed normalization of overijssel_34
# Performed normalization of overijssel_44
# Performed normalization of overijssel_43
# Performed normalization of overijssel_45
# Performed normalization of overijssel_46
# Performed normalization of overijssel_56
# Performed normalization of overijssel_59
# Performed normalization of overijssel_57
# Performed normalization of overijssel_58
# Performed normalization of overijssel_60
# Performed normalization of overijssel_70
# Performed normalization of overijssel_71
# Performed normalization of overijssel_74
# Performed normalization of overijssel_84
# Performed normalization of overijssel_98
# Performed normalization of zeeland_3
# Performed normalization of zeeland_4
# Performed normalization of zeeland_5
# Performed normalization of zeeland_7
# Performed normalization of zeeland_6
# Performed normalization of zeeland_8
# Performed normalization of zeeland_9
# Performed normalization of zeeland_10
# Performed normalization of zeeland_18
# Performed normalization of zeeland_19
# Performed normalization of zeeland_20
# Performed normalization of zeeland_21
# Performed normalization of zeeland_23
# Performed normalization of zeeland_22
# Performed normalization of zeeland_24
# Performed normalization of zeeland_31
# Performed normalization of zeeland_33
# Performed normalization of zeeland_32
# Performed normalization of zeeland_35
# Performed normalization of zeeland_34
# Performed normalization of zeeland_36
# Performed normalization of zeeland_37
# Performed normalization of zeeland_47
# Performed normalization of zeeland_48
# Performed normalization of zeeland_50
# Performed normalization of zeeland_49
# Performed normalization of zeeland_51
# Performed normalization of zeeland_62
# Performed normalization of zeeland_63
# Performed normalization of zeeland_64
# Performed normalization of zeeland_76
# Performed normalization of zeeland_77
# Performed normalization of zuid-holland_101
# Performed normalization of zuid-holland_100
# Performed normalization of zuid-holland_114

# %%
# ################################################################
# Network builder functions
#
# Dynamic builder function for the FCN-DK and U-Net
# Supported are the layers 2 up to and including 6.
# ################################################################

#import model_segnet_Nbands

from keras.layers import Activation, BatchNormalization, Convolution2D, LeakyReLU, Reshape, ZeroPadding2D
from keras.models import Sequential
# TODO: Consider which optimizer is the best
from keras.optimizers import SGD, Adam


from keras_unet.models import satellite_unet

def build_unet(
    x: int,
    y: int,
    bands: int,
    labels: int,
    layers: int = 2,
) -> tf.keras.Model:
    """Create  a model of the popular U-Net network.

    :param x: Number of rows (x-shape)
    :param y: Number of columns (y-shape)
    :param bands: Number of bands (z-shape)
    :param lables: Number of labels to predict with the network
    :param layers: Number of layers of the network
    :return: Model of the corresponding U-Net network
    """
    model = satellite_unet(
        input_shape=(x, y, bands),
        num_classes=labels,
        output_activation="softmax",
        num_layers=layers,
    )
    return model

def build_unet2(
    x: int,
    y: int,
    bands: int,
    labels: int,
) -> tf.keras.Model:
    """Wrapper function to build an UNet with 2 layers
    """
    return build_unet(x, y, bands, labels, layers=2)
    
def build_unet3(
    x: int,
    y: int,
    bands: int,
    labels: int,
) -> tf.keras.Model:
    """Wrapper function to build an UNet with 3 layers
    """
    return build_unet(x, y, bands, labels, layers=3)
    


def build_fcndk(
    x: int,
    y: int,
    bands: int,
    labels: int,
    layers=4,
) -> tf.keras.Model:
    """Build a new network model based on the configuration of the networks 
    FCNDK2, ..., FCNDK6. Specify the layers to use in the parameters.

    :param x: Number of rows
    :param y: Number of columns
    :param bands: Number of bands in the input images
    :param labels: Number of different labels to choose as the classification
    :param layers: The number of FCNDK layers; Should be between 2 and 6 [default: 4]
    :return: Model of the corresponding FCNDK network
    """
    """Model builder function for FCN-DK6."""
    model = keras.models.Sequential()
    model.add(ZeroPadding2D((2, 2), input_shape=(x, y, bands)))
    model.add(Convolution2D(
              filters=16,
              kernel_size=(5, 5),
              dilation_rate=(1, 1)))
    model.add(BatchNormalization(axis=3))
    model.add(LeakyReLU(0.1))

    if layers >= 2:
        # FCNDK2
        model.add(ZeroPadding2D((4, 4)))
        model.add(Convolution2D(
                filters=32,
                kernel_size=(5, 5),
                dilation_rate=(2, 2)
        ))
        model.add(BatchNormalization(axis=3))
        model.add(LeakyReLU(0.1))

    if layers >= 3:
        # FCNDK3
        model.add(ZeroPadding2D((6, 6)))
        model.add(Convolution2D(
                filters=32,
                kernel_size=(5, 5),
                dilation_rate=(3, 3)
        ))
        model.add(BatchNormalization(axis=3))
        model.add(LeakyReLU(0.1))

    if layers >= 4:
        # FCNDK4
        model.add(ZeroPadding2D((8, 8)))
        model.add(Convolution2D(
                filters=32,
                kernel_size=(5, 5),
                dilation_rate=(4, 4)
        ))
        model.add(BatchNormalization(axis=3))
        model.add(LeakyReLU(0.1))

    if layers >= 5:
        # FCNDK5
        model.add(ZeroPadding2D((10, 10)))
        model.add(Convolution2D(
                filters=32,
                kernel_size=(5, 5),
                dilation_rate=(5, 5)
        ))
        model.add(BatchNormalization(axis=3))
        model.add(LeakyReLU(0.1))

    if layers >= 6:
        # FCNDK6
        model.add(ZeroPadding2D((12, 12)))
        model.add(Convolution2D(
                filters=32,
                kernel_size=(5, 5),
                dilation_rate=(6, 6)
        ))
        model.add(BatchNormalization(axis=3))
        model.add(LeakyReLU(0.1))

    # Output layer
    model.add(Convolution2D(
              filters=labels,
              kernel_size=(1, 1)
    ))

    model.add(keras.layers.Activation(
              activation="softmax"
    ))
    return model

def build_fcndk3(
    x: int,
    y: int,
    bands: int,
    labels: int,
) -> tf.keras.Model:
    """Wrapper function to build an FCNDK with 3 layers
    """
    return build_fcndk(x, y, bands, labels, layers=3)
    
def build_fcndk4(
    x: int,
    y: int,
    bands: int,
    labels: int,
) -> tf.keras.Model:
    """Wrapper function to build an FCNDK with 4 layers
    """
    return build_fcndk(x, y, bands, labels, layers=4)

def build_fcndk5(
    x: int,
    y: int,
    bands: int,
    labels: int,
) -> tf.keras.Model:
    """Wrapper function to build an FCNDK with 5 layers
    """
    return build_fcndk(x, y, bands, labels, layers=5)

def build_fcndk6(
    x: int,
    y: int,
    bands: int,
    labels: int,
) -> tf.keras.Model:
    """Wrapper function to build an FCNDK with 6 layers
    """
    return build_fcndk(x, y, bands, labels, layers=6)


def build_network(name: str) -> typing.Callable:
    """Builds a new network, based on the networks name
    :param name: The networks name
    :return: The builder function of the corresponding network.
    """
    if name.lower() == "fcndk3":
        return build_fcndk3
    elif name.lower() == "fcndk4":
        return build_fcndk4
    elif name.lower() == "fcndk5":
        return build_fcndk5
    elif name.lower() == "fcndk6":
        return build_fcndk6
    elif name.lower() == "unet2":
        return build_unet2
    elif name.lower() == "unet3":
        return build_unet3
# Out:
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------

# %%
# ################################################################
# Creating network
#
# In this code block, the network configuration is loaded properly
# and the corresponding builder function is called.
# ################################################################

NUMBER_BANDS = 4
NUMBER_CLASSES = 2
NUMBER_EPOCHS = 10
NUMBER_BATCHES = 64
VALIDATION_SPLIT = 0.02

model_builder = build_network(NETWORK_NAME)

# Optimizer (actually  not required anymore, but code legacy requires it.)
if NETWORK_OPTIMIZER == "Adam":
    OPTIMIZER = tf.keras.optimizers.Adam(
        learning_rate=ADAM_LEARNING_RATE,
        beta_1=ADAM_BETA_1, 
        beta_2=ADAM_BETA_2, 
        epsilon=ADAM_EPSILON
    )
elif NETWORK_OPTIMIZER == "SGD":
    OPTIMIZER = tf.keras.optimizers.SGD(
        learning_rate=SGD_LEARNING_RATE, 
        momentum=SGD_MOMENTUM
    )

# Load existing network from files
m = import_model(NETWORK_UUID, NETWORK_NAME)
readme = m.readme
model = m.model
history = m.history
print(f"Load existing network: {NETWORK_UUID} {NETWORK_NAME}")

# Print configuration README before (possible) training
print(readme)
# Out:
# Imported README: /content/drive/My Drive/Minor: EO Project Group 3/Networks/371dd574-5b78-11eb-8f58-0242ac1c0002-UNet3-readme.txt
# Imported model: /content/drive/My Drive/Minor: EO Project Group 3/Networks/371dd574-5b78-11eb-8f58-0242ac1c0002-UNet3-model.h5
# Imported weights: /content/drive/My Drive/Minor: EO Project Group 3/Networks/371dd574-5b78-11eb-8f58-0242ac1c0002-UNet3-weights.h5
# Imported history: /content/drive/My Drive/Minor: EO Project Group 3/Networks/371dd574-5b78-11eb-8f58-0242ac1c0002-UNet3-history
# Load existing network: 371dd574-5b78-11eb-8f58-0242ac1c0002 UNet3
#
# Training configuration
# ================================
# Network
#     UUID:               371dd574-5b78-11eb-8f58-0242ac1c0002
#     Name:               UNet3
#     Optimizer:          Adam
#
# Parameters
#     Bands:              4
#     Classes:            2
#     Epochs:             600
#     Batch Size:         8
#
# Optimizer (Adam)
#     Learning Rate:      0.0015
#     Beta 1:             0.9
#     Beta 2:             0.999
#     Epsilon:            1e-06
#
# Execution summary
#     Patches:            433
#     Validation Split:   0.05
#     Resolution (px):    400x400
#     Bands:              4
#     Classes:            1
#
# Training Set:
#     (overijssel, 2)
#     (friesland, 178)
#     (flevoland, 36)
#     (zeeland, 77)
#     (friesland, 195)
#     (flevoland, 21)
#     (zeeland, 18)
#     (overijssel, 43)
#     (overijssel, 60)
#     (zeeland, 35)
#     (overijssel, 1)
#     (flevoland, 50)
#     (limburg, 166)
#     (overijssel, 18)
#     (zeeland, 5)
#     (zeeland, 8)
#     (flevoland, 22)
#     (zeeland, 31)
#     (flevoland, 80)
#     (limburg, 165)
#     (zeeland, 51)
#     (friesland, 136)
#     (overijssel, 74)
#     (overijssel, 17)
#     (flevoland, 34)
#     (zeeland, 6)
#     (friesland, 135)
#     (flevoland, 108)
#     (zeeland, 21)
#     (overijssel, 32)
#     (zeeland, 24)
#     (flevoland, 93)
#     (friesland, 163)
#     (flevoland, 64)
#     (overijssel, 6)
#     (zeeland, 3)
#     (friesland, 152)
#     (zeeland, 22)
#     (friesland, 151)
#     (flevoland, 94)
#     (overijssel, 5)
#     (friesland, 179)
#     (flevoland, 37)
#     (overijssel, 84)
#     (gelderland, 29)
#     (zeeland, 19)
#     (zeeland, 32)
#     (flevoland, 51)
#     (friesland, 180)
#     (overijssel, 21)
#     (zuid-holland, 101)
#     (zeeland, 9)
#     (friesland, 175)
#     (overijssel, 58)
#     (overijssel, 15)
#     (friesland, 137)
#     (overijssel, 16)
#     (zeeland, 7)
#     (zeeland, 10)
#     (overijssel, 35)
#     (limburg, 82)
#     (flevoland, 65)
#     (overijssel, 57)
#     (overijssel, 71)
#     (friesland, 138)
#     (overijssel, 31)
#     (zeeland, 23)
#     (zuid-holland, 114)
#     (overijssel, 46)
#     (friesland, 148)
#     (flevoland, 95)
#     (friesland, 165)
#     (flevoland, 66)
#     (overijssel, 4)
#     (limburg, 96)
#     (friesland, 176)
#     (gelderland, 37)
#     (zeeland, 62)
#     (friesland, 123)
#     (overijssel, 45)
#     (zeeland, 33)
#     (friesland, 166)
#     (flevoland, 79)
#     (overijssel, 20)
#     (zeeland, 76)
#     (flevoland, 20)
#     (zeeland, 34)
#     (overijssel, 14)
#     (zeeland, 49)
#     (zeeland, 4)
#     (overijssel, 34)
#     (friesland, 161)
#     (overijssel, 56)
#     (zeeland, 47)
#     (zeeland, 50)
#     (overijssel, 30)
#     (friesland, 134)
#     (zeeland, 20)
#     (friesland, 149)
#     (overijssel, 33)
#     (zeeland, 37)
#     (friesland, 162)
#     (overijssel, 7)
#     (friesland, 177)
#     (zeeland, 63)
#     (zeeland, 64)
#     (overijssel, 29)
#     (friesland, 150)
#     (overijssel, 44)
# Test Set:
#     (zeeland, 36)
#     (flevoland, 52)
#     (overijssel, 70)
#     (friesland, 164)
#     (limburg, 110)
#     (overijssel, 98)
#     (overijssel, 3)
#     (overijssel, 59)
#     (flevoland, 107)
#     (gelderland, 30)
#     (zeeland, 48)
#     (overijssel, 19)
#     (zuid-holland, 100)

# %%
# ################################################################
# Predictions & export
#
# Here, the network is fed with the given input files. Resulting
# predictions are exported as TIF files.
# ################################################################

from matplotlib import pyplot
from PIL import Image

def evaluate_predictions(
    input: np.ndarray,
    nc: int,
    f_weights: str,
    optimizer: tf.keras.optimizers.Optimizer,
    model_builder: typing.Callable,
) -> np.ndarray:
    """Takes an input image, patches it into smaller patches and feeds the FCN
    with each of the patches. The output samples are patches of the predicted
    classification. These patches are combined into one large image, that can
    be compared with the classified image of the corresponding input data.

    :param input: test image to evaluate
    :param nc: Number of classes/labels
    :param f_weights: File path to the corresponding weights file
    :param optimizer: Optimizer for the network
    :param model_build: method to create the model
    :return: 2D ndarray of the predicted labels
    """
    x, y, bands = input.shape

    # Build model and load model weights
    model = model_builder(x, y, bands, nc)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics='accuracy')
    model.load_weights(f_weights)

    # Predict field boundaries in network
    # Increase dimension to perform batch prediction
    input = np.expand_dims(input, 0)
    prediction = model.predict(input)[0]
    # Map highest score onto label
    prediction = np.argmax(prediction, axis=2) + 1
    
    return prediction

def export_array(labels: np.ndarray, filename: str):
    """Maps labels onto the colors black & white and exports the resulting image
    as a file with the given file.

    :param labels: 2D array of labels per pixel
    :param filename: File name of the new file
    """
    x, y = labels.shape

    img = np.zeros((x, y, 3), dtype=np.uint8)

    for i in range(img.shape[2]):
        img[:, :, i] = np.where(labels[:, :] == 2, 255, 0)

    Image.fromarray(img).save(filename)
    #Image.fromarray(img).save()
    #pyplot.imsave(filename, Image.fromarray(img))

# %%
# ################################################################
# Predict images and store as TIF
# 
# This code block will iterate through the included folders and
# performs predictions on the satellite image tiles. The resulting
# images are mapped onto black & white and then exported as TIF
# files
# ################################################################

import pathlib


keys_per_province = dict()

for f in INCLUDE_FOLDERS:
    keys_per_province[f] = [k for k in x_dict.keys() if k[0].lower() == f.lower()]


for f, keys in keys_per_province.items():
    for k in keys:
        x = x_dict[k]

        (_, _, f_weights, _) = get_file_names(NETWORK_UUID, NETWORK_NAME)

        try:
            img = evaluate_predictions(
                x,
                NUMBER_CLASSES,
                f_weights,
                OPTIMIZER,
                model_builder,
            )
        except Exception as e:
            print(f"Failed to predict image of size {x.shape[0]}x{x.shape[1]}")
            continue

        # Build directory name
        fname = DATA_PATH
        fname += f"{f}/"
        fname += f"Prediction_{NETWORK_NAME}/"

        # Create directory
        pathlib.Path(fname).mkdir(parents=True, exist_ok=True)

        # build filename
        fname += f"prediction_{k[0]}_{k[1]}"
        fname += ".tif"

        export_array(img, fname)
        print(f"Exported prediction {fname}")
# Out:
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_21.tif
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_22.tif
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_20.tif
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_34.tif
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0f43a950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_36.tif
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0e267ae8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_37.tif
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0428f0d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_50.tif
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc040a2e18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_52.tif
# WARNING:tensorflow:9 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0fff6d90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_51.tif
# WARNING:tensorflow:10 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0e0b8158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_66.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0ff42f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_64.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc04333510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_65.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0e19ed90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_79.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc16053488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_80.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0e0698c8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_95.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc040a2ae8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_93.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc040b6d90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_94.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efbff7f0158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_107.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc7f0acf28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Flevoland/Prediction_UNet3/prediction_flevoland_108.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc040a2e18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_123.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0e1fa620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_134.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0e0e6620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_135.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc041b9d90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_137.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0f497ae8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_136.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0e197ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_138.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efbfee46730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_149.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0fe5d158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_148.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc04229378> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_150.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc04229e18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_151.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0fff6730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_152.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0ff3bea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_161.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0ff3f730> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_163.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc040407b8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_162.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc160c6ae8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_165.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0fff6598> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_164.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0fe290d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_166.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0429b510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_175.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0e2e4f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_177.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc04463c80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_176.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0ff7ca60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_178.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0f4e16a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_179.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0eb90510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Friesland/Prediction_UNet3/prediction_friesland_180.tif
# Failed to predict image of size 580x580
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0fe8cbf8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Gelderland/Prediction_UNet3/prediction_gelderland_29.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0f497a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Gelderland/Prediction_UNet3/prediction_gelderland_30.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc04581ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Gelderland/Prediction_UNet3/prediction_gelderland_37.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc044b6bf8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Limburg/Prediction_UNet3/prediction_limburg_82.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0eba96a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Limburg/Prediction_UNet3/prediction_limburg_96.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0ffb1f28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Limburg/Prediction_UNet3/prediction_limburg_110.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc043302f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Limburg/Prediction_UNet3/prediction_limburg_165.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0f497d08> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Limburg/Prediction_UNet3/prediction_limburg_166.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0fef6620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Overijssel/Prediction_UNet3/prediction_overijssel_1.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0fe9df28> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Overijssel/Prediction_UNet3/prediction_overijssel_2.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efbff7ef7b8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Overijssel/Prediction_UNet3/prediction_overijssel_5.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0fff6b70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Overijssel/Prediction_UNet3/prediction_overijssel_3.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0e0c8400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Overijssel/Prediction_UNet3/prediction_overijssel_4.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0ff3bea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Overijssel/Prediction_UNet3/prediction_overijssel_6.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0f505048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Overijssel/Prediction_UNet3/prediction_overijssel_7.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc04268048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zeeland/Prediction_UNet3/prediction_zeeland_33.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0e31ca60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zeeland/Prediction_UNet3/prediction_zeeland_32.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0fff6268> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zeeland/Prediction_UNet3/prediction_zeeland_35.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc16053e18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zeeland/Prediction_UNet3/prediction_zeeland_34.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0f46b488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zeeland/Prediction_UNet3/prediction_zeeland_36.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc04163268> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zeeland/Prediction_UNet3/prediction_zeeland_37.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0fe82b70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zeeland/Prediction_UNet3/prediction_zeeland_47.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc04581488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zeeland/Prediction_UNet3/prediction_zeeland_48.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc04042e18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zeeland/Prediction_UNet3/prediction_zeeland_50.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc04295d08> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zeeland/Prediction_UNet3/prediction_zeeland_49.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0fdd8bf8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zeeland/Prediction_UNet3/prediction_zeeland_51.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0e124620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zeeland/Prediction_UNet3/prediction_zeeland_62.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0e1fb378> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zeeland/Prediction_UNet3/prediction_zeeland_63.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0e0530d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zeeland/Prediction_UNet3/prediction_zeeland_64.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0420c2f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zeeland/Prediction_UNet3/prediction_zeeland_76.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc04581048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zeeland/Prediction_UNet3/prediction_zeeland_77.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc040d22f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zuid-Holland/Prediction_UNet3/prediction_zuid-holland_101.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc040d2e18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zuid-Holland/Prediction_UNet3/prediction_zuid-holland_100.tif
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc0420c0d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Exported prediction /content/drive/My Drive/Minor: EO Project Group 3/Classified Data/Zuid-Holland/Prediction_UNet3/prediction_zuid-holland_114.tif
